# %%
""" Este script extrae información de los campos del HTML 
    del cvlac a partir de una base de datos inicial de los perfiles
"""
# Importar librerias/Modulos
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
from lxml import html
import scrapy
import time

# %%
#Find_tags = lambda tag, base: base.find_all(tag)
#Find_tag = lambda tag, base: base.find_next(tag)
#Find_tags_next = lambda tag, base: base.find_all_next(tag)

# %%
# Extrae metadatos de la página semilla


def pag_principal():
    n = 'todas'
    link = 'https://minciencias.gov.co/convocatorias/' + n

    encabezados = {
    'user-agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.157 Safari/537.36'
    }

    resp = requests.get(link, headers=encabezados, verify=False)
    resp = resp.text

    #soup = get_Soup('https://minciencias.gov.co/convocatorias/todas')
    parser = html.fromstring(resp)

    return parser

#Título
def titulo(parser):
    titulo = parser.xpath('//table[@class="views-table cols-5"]/tbody/tr/td[@class="views-field views-field-title"]/a/text()')
    return titulo

# Descripción
def descripcion(parser):
    
    descripcion = []
    for x in range(0,6):

        #descrip = parser.xpath('//table/tbody/tr[' + str(x) + ']/td[' + str(x) + ']/text()')
        descrip = parser.xpath('//table/tbody/tr['+str(x)+']/td[3]/text()')
        descripcion.append(descrip)
    decrip = []
    for x in descripcion[1:6]:
        des = x[0].strip()
        decrip.append(des) 

    
    return decrip

#Presupuesto
def cuantia(parser):
    cuantia = parser.xpath('//td[@class="views-field views-field-field-cuantia"]/text()')
    presupuesto = []
    for x in cuantia:
        x = x.strip()
        presupuesto.append(x)
    return presupuesto
#Fecha Apertura

def fecha_apertura(parser):
    
    fecha_apertura = parser.xpath('//table/tbody/tr//td[@class="views-field views-field-field-fecha-de-apertura"]/span/text()')
    fe_aper = []
    for x in fecha_apertura:
        x = x.strip()
        if x != '':
            fe_aper.append(x.strip())
    
    if len(fe_aper) < 5:
        fecha_apertura = parser.xpath('//table/tbody/tr//td[@class="views-field views-field-field-fecha-de-apertura"]//text()')
        fe_aper = []
        for x in fecha_apertura:
            x = x.strip()
            if x != '':
                fe_aper.append(x.strip())

    if len(fe_aper) < 5:
        fe_aper = []
        for x in range(0,6):
            fecha_apertura = parser.xpath('//table/tbody/tr[' + str(x) + ']/td[5]/text()')
            if len(fecha_apertura) == 0:
                x = ''
            else:
                for x in fecha_apertura:
                    x = x.strip()
                    #if x != '':
                    fe_aper.append(x.strip())

    return fe_aper

#Links scrapy vertical
def links_vertical(link):

    encabezados = {
        'user-agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.157 Safari/537.36'
        }

    resp = requests.get(link, headers=encabezados, verify=False)
    resp = resp.text

    response = scrapy.Selector(text=resp)
    
    final = response.xpath('//td[@class="views-field views-field-title"]/a/@href').getall()
    
    link = 'https://minciencias.gov.co'
    links = []
    for x in final:
        if x.startswith('http://'): 
            links.append(x)
        elif x.startswith('https://'): 
            links.append(x)
        else:
            links.append(link+x)
    return links

def ult_page(url):    
    
    encabezados = {
        'user-agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.157 Safari/537.36'
        }

    resp = requests.get(url, headers=encabezados, verify=False)
    resp = resp.text    

    response = scrapy.Selector(text=resp)

    ult = response.xpath('//li[@class="pager-last last"]/a/@href').getall()

    ult2 = ult[0].split('=')[1]
    
    return ult2

### Vertical

def pag_vertical(link):
    try:
        encabezados = {
        'user-agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.157 Safari/537.36'
        }

        resp = requests.get(link, headers=encabezados, verify=False)
        resp = resp.text

        #soup = get_Soup('https://minciencias.gov.co/convocatorias/todas')
        parser = html.fromstring(resp)
    except:
        parser = 'http://www.rutanmedellin.org/es/actualidad/noticias/item/abierta-convocatoria-para-solucionar-retos-energeticos-empresariales'


    return parser

def objetivo(parser):
    try:
        objetivo = parser.xpath('//div[@class="field-items"][2]/div[@class="field-item even"]/text()')
        objetivo_pro = objetivo[0].strip()
    except IndexError:
        objetivo_pro = ''
    except AttributeError:
        objetivo_pro = ''
    return objetivo_pro

def publico_objetivo(parser):
    try:
        diri_a = parser.xpath('//div[@class="body2-convocatorias"]//div[@class="field-item even"]//text()')

        n=0
        dirigido_a = ''

        for elemento in diri_a:
            elemento = elemento.strip()
            if elemento != '':
                dirigido_a = dirigido_a + ' ' + elemento
                n+=1

        dirigido_a.strip()
    except AttributeError:
        dirigido_a = ''
    return dirigido_a

def estado(parser):
    try:
        estado = parser.xpath('//div[@class="sub-sub-panel panel-state-tex"]/p/text()')
        estado = estado[0] + ' ' + estado[1]
    except IndexError:
        estado = ''
    except AttributeError:
        estado = ''
    return estado

def fechas_cierre(parser):
    
    try:
        marcas = parser.xpath('//tr/td[@class="views-field views-field-field-numero"]/text()')
        estados = []
        fecha2 = ''
        for i in marcas:
            estados.append(i.strip())
            
        for x in range(len(estados)):
            marca = parser.xpath('//tr/td[@class="views-field views-field-field-numero"][1]/text()')[x]
            if marca.strip() in estados:
                fecha = parser.xpath('//tr/td[@class="views-field views-field-body"]/text()')[x]
                if marca.strip() == 'Cierre':
                    fecha2 = fecha.strip()
                    break
                else:
                    fecha2 = ''
    except IndexError:
        fecha2 = ''
    except AttributeError:
        fecha2 = ''

    return fecha2.strip()

def fechas_resultados_preliminares(parser):
    
    try:
        marcas = parser.xpath('//tr/td[@class="views-field views-field-field-numero"]/text()')
        estados = []
        fecha2 = ''
        for i in marcas:
            estados.append(i.strip())
            
        for x in range(len(estados)):
            marca = parser.xpath('//tr/td[@class="views-field views-field-field-numero"][1]/text()')[x]
            if marca.strip() in estados:
                fecha = parser.xpath('//tr/td[@class="views-field views-field-body"]/text()')[x]
                if marca.strip() == 'Publicación de resultados preliminares':
                    fecha2 = fecha.strip()
                    break
                else:
                    fecha2 = ''
    except IndexError:
        fecha2 = ''
    except AttributeError:
        fecha2 = ''
                
    return fecha2.strip()

def fechas_publicacion_resultados_definitivos(parser):
    try:
        marcas = parser.xpath('//tr/td[@class="views-field views-field-field-numero"]/text()')
        estados = []
        fecha2 = ''
        for i in marcas:
            estados.append(i.strip())

        for x in range(len(estados)):
            marca = parser.xpath('//tr/td[@class="views-field views-field-field-numero"][1]/text()')[x]
            if marca.strip() in estados:
                fecha = parser.xpath('//tr/td[@class="views-field views-field-body"]/text()')[x]
                if marca.strip() == 'Publicación de resultados definitivos' or marca.strip() == 'Publicación de resultados  definitivos':
                    fecha2 = fecha.strip()
                    break
                else:
                    fecha2 = ''
    except IndexError:
        fecha2 = ''
    except AttributeError:
        fecha2 = ''
        
    return fecha2.strip()

def links_pdf(link):
    try:
        encabezados = {
            'user-agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.157 Safari/537.36'
            }

        resp = requests.get(link, headers=encabezados, verify=False)
        resp = resp.text    

        response = scrapy.Selector(text=resp)

        links = response.xpath('//span[@class="file"]/a/@href').getall()
        
        urls = ''
        for link in links:
            urls = urls + ', ' + link
        
        urls = urls[2::]
    except ConnectionError:
        urls = ''
    except MaxRetryError:
        urls = ''

    return urls


def pag_horizontal(link):
    
    
    encabezados = {
    'user-agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.157 Safari/537.36'
    }

    resp = requests.get(link, headers=encabezados, verify=False)
    resp = resp.text

    #soup = get_Soup('https://minciencias.gov.co/convocatorias/todas')
    parser = html.fromstring(resp)

    return parser

# %%
def colombia():
    #   Página principal
    #   Configuración
    colombia = pd.DataFrame()
    parser = pag_principal()
    
    #   Extracción página principal

    tit = titulo(parser)
    desc = descripcion(parser)
    cuant = cuantia(parser)
    aper = fecha_apertura(parser)
    links = links_vertical('https://minciencias.gov.co/convocatorias/todas')
    
    #Vertical Primera página
    obj = []
    pub_objetivo = []
    est= []
    fe_cierre = []
    fe_preliminares = []
    fe_definitivos = []
    pdf = []
    

    for link in links:
        parser = pag_vertical(link)

        obj.append(objetivo(parser))
        pub_objetivo.append(publico_objetivo(parser))
        est.append(estado(parser))
        fe_cierre.append(fechas_cierre(parser))
        fe_preliminares.append(fechas_resultados_preliminares(parser))
        fe_definitivos.append(fechas_publicacion_resultados_definitivos(parser))
        pdf.append(links_pdf(link))
    
        #   CSV
    colombia['Título'] = tit
    colombia['Descripción'] = desc
    colombia['Objetivo'] = obj
    colombia['Cuantia'] = cuant
    colombia['Fecha Apertura'] = aper
    colombia['Fecha Cierre'] = fe_cierre
    colombia['Fecha Resultados Preliminares'] = fe_preliminares
    colombia['Fecha Publicación Resultados Definitivos'] = fe_definitivos
    colombia['Link'] = links
    colombia['Público Objetivo'] = pub_objetivo
    colombia['Estado de la Convocatoria'] = est
    colombia['Links pdf'] = pdf

    #Horizontal
    ult = ult_page('https://minciencias.gov.co/convocatorias/todas?page=1')

    for pag in range(1, int(ult)):
        
        print(pag)
        
        url = 'https://minciencias.gov.co/convocatorias/todas?page=' + str(pag)
        horizontal = pd.DataFrame()
        parser = pag_horizontal(url)
        

            #   Extracción página principal

        tit = titulo(parser)
        desc = descripcion(parser)
        cuant = cuantia(parser)
        aper = fecha_apertura(parser)
        links = links_vertical(url)
            
            #Vertical Primera página
        obj = []
        pub_objetivo = []
        est= []
        fe_cierre = []
        fe_preliminares = []
        fe_definitivos = []
        pdf = []
  
        for link in links:
            print(link)
            parser = pag_vertical(link)

            obj.append(objetivo(parser))
            pub_objetivo.append(publico_objetivo(parser))
            est.append(estado(parser))
            fe_cierre.append(fechas_cierre(parser))
            fe_preliminares.append(fechas_resultados_preliminares(parser))
            fe_definitivos.append(fechas_publicacion_resultados_definitivos(parser))
            pdf.append(links_pdf(link))
            

                        #   CSV
        horizontal['Título'] = tit
        horizontal['Descripción'] = desc
        horizontal['Objetivo'] = obj
        horizontal['Cuantia'] = cuant
        horizontal['Fecha Apertura'] = aper
        horizontal['Fecha Cierre'] = fe_cierre
        horizontal['Fecha Resultados Preliminares'] = fe_preliminares
        horizontal['Fecha Publicación Resultados Definitivos'] = fe_definitivos
        horizontal['Link'] = links
        horizontal['Público Objetivo'] = pub_objetivo
        horizontal['Estado de la Convocatoria'] = est
        horizontal['Links pdf'] = pdf

        colombia = colombia.append(horizontal)
        colombia.reset_index(drop=True, inplace=True)
        

    return colombia


kk = colombia()
# Out:
# 1
# https://minciencias.gov.co/node/5618
# https://minciencias.gov.co/node/5594
# https://minciencias.gov.co/node/5320
# https://minciencias.gov.co/node/5517
# https://minciencias.gov.co/node/5316
# 2
# https://minciencias.gov.co/node/5460
# https://minciencias.gov.co/node/5456
# https://minciencias.gov.co/node/5454
# https://minciencias.gov.co/node/5444
# https://minciencias.gov.co/node/5442
# 3
# https://minciencias.gov.co/node/5441
# https://minciencias.gov.co/node/5406
# https://minciencias.gov.co/node/5383
# https://minciencias.gov.co/node/5315
# https://minciencias.gov.co/node/5312
# 4
# https://minciencias.gov.co/node/5317
# https://minciencias.gov.co/node/5146
# https://minciencias.gov.co/node/5133
# https://minciencias.gov.co/node/5020
# https://minciencias.gov.co/node/5019
# 5
# https://minciencias.gov.co/node/4899
# https://minciencias.gov.co/node/3857
# https://minciencias.gov.co/node/4897
# https://minciencias.gov.co/node/4847
# https://minciencias.gov.co/node/4751
# 6
# https://minciencias.gov.co/node/3831
# https://minciencias.gov.co/node/3837
# https://minciencias.gov.co/node/3840
# https://minciencias.gov.co/node/3842
# https://minciencias.gov.co/node/3824
# 7
# https://minciencias.gov.co/node/3838
# https://minciencias.gov.co/node/3855
# https://minciencias.gov.co/node/3845
# https://minciencias.gov.co/node/3856
# https://minciencias.gov.co/node/4410
# 8
# https://minciencias.gov.co/node/4385
# https://minciencias.gov.co/node/4384
# https://minciencias.gov.co/node/3859
# https://minciencias.gov.co/node/4356
# https://minciencias.gov.co/node/3854
# 9
# https://minciencias.gov.co/node/3852
# https://minciencias.gov.co/node/3825
# https://minciencias.gov.co/node/3853
# https://minciencias.gov.co/node/3841
# https://minciencias.gov.co/node/3843
# 10
# https://minciencias.gov.co/node/4062
# https://minciencias.gov.co/node/4061
# https://minciencias.gov.co/node/4063
# https://minciencias.gov.co/node/4064
# https://minciencias.gov.co/node/4059
# 11
# https://minciencias.gov.co/node/3844
# https://minciencias.gov.co/node/4039
# https://minciencias.gov.co/node/4005
# https://minciencias.gov.co/node/3862
# https://minciencias.gov.co/node/3829
# 12
# https://minciencias.gov.co/node/3830
# https://minciencias.gov.co/node/3715
# https://minciencias.gov.co/node/3655
# https://minciencias.gov.co/node/3654
# https://minciencias.gov.co/node/3599
# 13
# https://minciencias.gov.co/node/3566
# https://minciencias.gov.co/node/3565
# https://minciencias.gov.co/node/3564
# https://minciencias.gov.co/node/3507
# https://minciencias.gov.co/node/3455
# 14
# https://minciencias.gov.co/node/2981
# https://minciencias.gov.co/node/3163
# https://minciencias.gov.co/node/3164
# https://minciencias.gov.co/node/3165
# https://minciencias.gov.co/node/3162
# 15
# https://minciencias.gov.co/node/2990
# https://minciencias.gov.co/node/3006
# https://minciencias.gov.co/node/2986
# https://minciencias.gov.co/node/2985
# https://minciencias.gov.co/node/2996
# 16
# https://minciencias.gov.co/node/2980
# https://minciencias.gov.co/node/2995
# https://minciencias.gov.co/node/2993
# https://minciencias.gov.co/node/3007
# https://minciencias.gov.co/node/3067
# 17
# https://minciencias.gov.co/node/3068
# https://minciencias.gov.co/node/3004
# https://minciencias.gov.co/node/3005
# https://minciencias.gov.co/node/2999
# https://minciencias.gov.co/node/3002
# 18
# https://minciencias.gov.co/node/3003
# https://minciencias.gov.co/node/3001
# https://minciencias.gov.co/node/3000
# https://minciencias.gov.co/node/2977
# https://minciencias.gov.co/node/2976
# 19
# https://minciencias.gov.co/node/2979
# https://minciencias.gov.co/node/2978
# https://minciencias.gov.co/node/2922
# https://minciencias.gov.co/node/2845
# https://minciencias.gov.co/node/2835
# 20
# https://minciencias.gov.co/node/2834
# https://minciencias.gov.co/node/2234
# https://minciencias.gov.co/node/2820
# https://minciencias.gov.co/node/2747
# https://minciencias.gov.co/node/2218
# 21
# https://minciencias.gov.co/node/2227
# https://minciencias.gov.co/node/2229
# https://minciencias.gov.co/node/2228
# https://minciencias.gov.co/node/2991
# https://minciencias.gov.co/node/2230
# 22
# https://minciencias.gov.co/node/2201
# https://minciencias.gov.co/node/2203
# https://minciencias.gov.co/node/2200
# https://minciencias.gov.co/node/2211
# https://minciencias.gov.co/node/2219
# 23
# https://minciencias.gov.co/node/2421
# https://minciencias.gov.co/node/2202
# https://minciencias.gov.co/node/2214
# https://minciencias.gov.co/node/2210
# https://minciencias.gov.co/node/2212
# 24
# https://minciencias.gov.co/node/2215
# https://minciencias.gov.co/node/2225
# https://minciencias.gov.co/node/2206
# https://minciencias.gov.co/node/2114
# https://minciencias.gov.co/node/2113
# 25
# https://minciencias.gov.co/node/2112
# https://minciencias.gov.co/node/1323
# https://minciencias.gov.co/node/1316
# https://minciencias.gov.co/node/1878
# https://minciencias.gov.co/node/1783
# 26
# https://minciencias.gov.co/node/1730
# https://minciencias.gov.co/node/1634
# https://minciencias.gov.co/node/1635
# https://minciencias.gov.co/node/1309
# https://minciencias.gov.co/node/1326
# 27
# https://minciencias.gov.co/node/1327
# https://minciencias.gov.co/node/1559
# https://minciencias.gov.co/node/1526
# https://minciencias.gov.co/node/1308
# https://minciencias.gov.co/node/1307
# 28
# https://minciencias.gov.co/node/843
# https://minciencias.gov.co/node/842
# https://minciencias.gov.co/node/841
# https://minciencias.gov.co/node/840
# https://minciencias.gov.co/node/839
# 29
# https://minciencias.gov.co/node/1324
# https://minciencias.gov.co/node/1320
# https://minciencias.gov.co/node/1314
# https://minciencias.gov.co/node/1318
# https://minciencias.gov.co/node/1319
# 30
# https://minciencias.gov.co/node/1313
# https://minciencias.gov.co/node/1312
# https://minciencias.gov.co/node/1325
# https://minciencias.gov.co/node/780
# https://minciencias.gov.co/node/779
# 31
# https://minciencias.gov.co/node/778
# https://minciencias.gov.co/node/777
# https://minciencias.gov.co/node/776
# https://minciencias.gov.co/node/775
# https://minciencias.gov.co/node/774
# 32
# https://minciencias.gov.co/node/773
# https://minciencias.gov.co/node/772
# https://minciencias.gov.co/node/771
# https://minciencias.gov.co/node/770
# https://minciencias.gov.co/node/769
# 33
# https://minciencias.gov.co/node/768
# https://minciencias.gov.co/node/767
# https://minciencias.gov.co/node/766
# https://minciencias.gov.co/node/765
# https://minciencias.gov.co/node/764
# 34
# https://minciencias.gov.co/node/763
# https://minciencias.gov.co/node/762
# https://minciencias.gov.co/node/761
# https://minciencias.gov.co/node/760
# https://minciencias.gov.co/node/834
# 35
# https://minciencias.gov.co/node/758
# https://minciencias.gov.co/node/757
# https://minciencias.gov.co/node/756
# https://minciencias.gov.co/node/755
# https://minciencias.gov.co/node/754
# 36
# https://minciencias.gov.co/node/753
# https://minciencias.gov.co/node/752
# https://minciencias.gov.co/node/751
# https://minciencias.gov.co/node/750
# https://minciencias.gov.co/node/749
# 37
# https://minciencias.gov.co/node/748
# https://minciencias.gov.co/node/747
# https://minciencias.gov.co/node/746
# https://minciencias.gov.co/node/745
# https://minciencias.gov.co/node/744
# 38
# https://minciencias.gov.co/node/743
# https://minciencias.gov.co/node/742
# https://minciencias.gov.co/node/741
# https://minciencias.gov.co/node/740
# https://minciencias.gov.co/node/739
# 39
# https://minciencias.gov.co/node/738
# https://minciencias.gov.co/node/737
# https://minciencias.gov.co/node/736
# https://minciencias.gov.co/node/720
# https://minciencias.gov.co/node/719
# 40
# https://minciencias.gov.co/node/717
# https://minciencias.gov.co/node/710
# https://minciencias.gov.co/node/709
# https://minciencias.gov.co/node/708
# https://minciencias.gov.co/node/707
# 41
# https://minciencias.gov.co/node/706
# https://minciencias.gov.co/node/705
# https://minciencias.gov.co/node/704
# https://minciencias.gov.co/node/703
# https://minciencias.gov.co/node/702
# 42
# https://minciencias.gov.co/node/701
# https://minciencias.gov.co/node/700
# https://minciencias.gov.co/node/699
# https://minciencias.gov.co/node/695
# https://minciencias.gov.co/node/694
# 43
# https://minciencias.gov.co/node/693
# https://minciencias.gov.co/node/692
# https://minciencias.gov.co/node/691
# https://minciencias.gov.co/node/690
# https://minciencias.gov.co/node/689
# 44
# https://minciencias.gov.co/node/688
# https://minciencias.gov.co/node/687
# https://minciencias.gov.co/node/686
# https://minciencias.gov.co/node/685
# https://minciencias.gov.co/node/684
# 45
# https://minciencias.gov.co/node/683
# https://minciencias.gov.co/node/682
# https://minciencias.gov.co/node/681
# https://minciencias.gov.co/node/680
# https://minciencias.gov.co/node/679
# 46
# https://minciencias.gov.co/node/678
# https://minciencias.gov.co/node/677
# https://minciencias.gov.co/node/676
# https://minciencias.gov.co/node/675
# https://minciencias.gov.co/node/674
# 47
# https://minciencias.gov.co/node/673
# https://minciencias.gov.co/node/672
# https://minciencias.gov.co/node/671
# https://minciencias.gov.co/node/670
# https://minciencias.gov.co/node/669
# 48
# https://minciencias.gov.co/node/668
# https://minciencias.gov.co/node/667
# https://minciencias.gov.co/node/666
# https://minciencias.gov.co/node/665
# https://minciencias.gov.co/node/664
# 49
# https://minciencias.gov.co/node/663
# https://minciencias.gov.co/node/662
# https://minciencias.gov.co/node/661
# https://minciencias.gov.co/node/660
# https://minciencias.gov.co/node/659
# 50
# https://minciencias.gov.co/node/658
# https://minciencias.gov.co/node/657
# https://minciencias.gov.co/node/656
# https://minciencias.gov.co/node/655
# https://minciencias.gov.co/node/654
# 51
# https://minciencias.gov.co/node/5899
# https://minciencias.gov.co/node/5821
# https://minciencias.gov.co/node/5812
# https://minciencias.gov.co/node/5760
# https://minciencias.gov.co/node/5745
# 52
# https://minciencias.gov.co/node/5719
# https://minciencias.gov.co/node/5675
# https://minciencias.gov.co/node/5651
# https://minciencias.gov.co/node/5575
# https://minciencias.gov.co/node/5490
# 53
# https://minciencias.gov.co/node/5483
# https://minciencias.gov.co/node/5141
# https://minciencias.gov.co/node/5451
# https://minciencias.gov.co/node/5429
# https://minciencias.gov.co/node/5408
# 54
# https://minciencias.gov.co/node/5357
# https://minciencias.gov.co/node/5469
# https://minciencias.gov.co/node/5267
# https://minciencias.gov.co/node/5264
# https://minciencias.gov.co/node/5252
# 55
# https://minciencias.gov.co/node/5251
# https://minciencias.gov.co/node/5199
# https://minciencias.gov.co/node/5163
# https://minciencias.gov.co/node/5012
# https://minciencias.gov.co/node/4866
# 56
# https://minciencias.gov.co/node/4743
# https://minciencias.gov.co/node/4717
# https://minciencias.gov.co/node/4680
# https://minciencias.gov.co/node/4675
# https://minciencias.gov.co/node/4672
# 57
# https://minciencias.gov.co/node/4589
# https://minciencias.gov.co/node/4514
# https://minciencias.gov.co/node/4488
# https://minciencias.gov.co/node/4443
# https://minciencias.gov.co/node/4344
# 58
# https://minciencias.gov.co/node/3834
# https://minciencias.gov.co/node/4289
# https://minciencias.gov.co/node/4134
# https://minciencias.gov.co/node/4081
# https://minciencias.gov.co/node/4018
# 59
# https://minciencias.gov.co/node/3996
# https://minciencias.gov.co/node/3827
# https://minciencias.gov.co/node/3942
# https://minciencias.gov.co/node/3858
# https://minciencias.gov.co/node/3805
# 60
# https://minciencias.gov.co/node/3828
# https://minciencias.gov.co/node/3744
# https://minciencias.gov.co/node/3740
# https://minciencias.gov.co/node/3714
# https://minciencias.gov.co/node/3628
# 61
# https://minciencias.gov.co/node/3627
# https://minciencias.gov.co/node/3567
# https://minciencias.gov.co/node/3512
# https://minciencias.gov.co/node/3470
# https://minciencias.gov.co/node/3451
# 62
# https://minciencias.gov.co/node/3441
# https://minciencias.gov.co/node/3435
# https://minciencias.gov.co/node/3421
# https://minciencias.gov.co/node/3412
# https://minciencias.gov.co/node/3318
# 63
# https://minciencias.gov.co/node/3312
# https://minciencias.gov.co/node/3316
# https://minciencias.gov.co/node/2997
# https://minciencias.gov.co/node/2988
# https://minciencias.gov.co/node/3233
# 64
# https://minciencias.gov.co/node/3209
# https://minciencias.gov.co/node/3175
# https://minciencias.gov.co/node/3168
# http://www.colciencias.gov.co/convocatorias/mentalidad-y-cultura/convocatoria-jovenes-investigadores-e-innovadores-en-alianza-sena
# https://minciencias.gov.co/node/2989
# 65
# https://minciencias.gov.co/node/3079
# https://minciencias.gov.co/node/3064
# https://minciencias.gov.co/node/3034
# https://minciencias.gov.co/node/2972
# https://minciencias.gov.co/node/2982
# 66
# https://minciencias.gov.co/node/2971
# https://minciencias.gov.co/node/2998
# https://minciencias.gov.co/node/2886
# https://minciencias.gov.co/node/2867
# https://minciencias.gov.co/node/2840
# 67
# https://minciencias.gov.co/node/2711
# https://minciencias.gov.co/node/2235
# https://minciencias.gov.co/node/2616
# https://minciencias.gov.co/node/2527
# https://minciencias.gov.co/node/2464
# 68
# https://minciencias.gov.co/node/2204
# https://minciencias.gov.co/node/2418
# https://minciencias.gov.co/node/2217
# https://minciencias.gov.co/node/2216
# https://minciencias.gov.co/node/2414
# 69
# http://www.rutanmedellin.org/es/actualidad/noticias/item/abierta-convocatoria-para-solucionar-retos-energeticos-empresariales
# https://minciencias.gov.co/node/2326
# https://minciencias.gov.co/node/2222
# https://minciencias.gov.co/node/2213
# https://minciencias.gov.co/node/2209
# 70
# https://minciencias.gov.co/node/2294
# http://www.fulbright.edu.co/Beca-Colciencias-Fulbright-2017
# https://www.innpulsacolombia.com/oferta/convocatoria-para-el-apoyo-la-proteccion-de-invenciones-con-potencial-de-mercado-v2
# https://minciencias.gov.co/node/2233
# https://minciencias.gov.co/node/2232
# 71
# http://www.colfuturo.org/convocatoria?gclid=CK764eLbvNECFQ0HhgodqdIFtQ
# https://minciencias.gov.co/node/2283
# https://minciencias.gov.co/node/2284
# https://minciencias.gov.co/node/2285
# https://minciencias.gov.co/node/2084
# 72
# https://minciencias.gov.co/node/2286
# https://minciencias.gov.co/node/2287
# https://minciencias.gov.co/node/2288
# https://minciencias.gov.co/node/1787
# http://www.colfuturo.org/convocatoria
# 73
# http://www.fulbright.edu.co/beca-colciencias-georgia-institute-of-technology
# http://www.fulbright.edu.co/beca-colciencias-fulbright
# http://www.acienciacierta.gov.co/
# http://www.fulbright.edu.co/beca-colciencias-georgia-institute-of-technology
# http://legadoweb.colciencias.gov.co/sites/default/files/ckeditor_files/files/alianzas.pdf
# 74
# http://www.colfuturo.org/financiacion-para-posgrados-en-el-exterior
# http://www.fulbright.edu.co/node/2171
# http://www.colfuturo.org/convocatoria
# https://minciencias.gov.co/node/849
# https://minciencias.gov.co/node/5323
# 75
# https://minciencias.gov.co/node/5319
# https://minciencias.gov.co/node/5295
# https://minciencias.gov.co/node/5149
# https://minciencias.gov.co/node/5145
# https://minciencias.gov.co/node/5142
# 76
# https://minciencias.gov.co/node/3863
# https://minciencias.gov.co/node/3836
# https://minciencias.gov.co/node/3835
# https://minciencias.gov.co/node/3584
# https://minciencias.gov.co/node/3010
# 77
# http://procurement-notices.undp.org/view_notice.cfm?notice_id=48342
# https://minciencias.gov.co/node/2992
# https://www.ccb.org.co/Eventos-y-capacitaciones/Nuestros-eventos/Conferencia/2018
# https://minciencias.gov.co/node/2983
# https://minciencias.gov.co/node/2975
# 78
# https://minciencias.gov.co/node/2974
# https://minciencias.gov.co/node/2282
# https://minciencias.gov.co/node/2231
# https://minciencias.gov.co/node/2221
# https://minciencias.gov.co/node/2220
# 79
# https://minciencias.gov.co/node/1786
# https://minciencias.gov.co/node/1785
# https://minciencias.gov.co/node/1784
# https://minciencias.gov.co/node/1317
# https://minciencias.gov.co/node/847

# %%
kk.to_excel('Colombia.xlsx')
